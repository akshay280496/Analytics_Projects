# %%
getwd()
# Out:
# [1] "D:/BABI/SMDM/Group-Assignment/Problem1"

# %%
setwd("D:/BABI/SMDM/Group-Assignment/Problem1")
getwd()
# Out:
# [1] "D:/BABI/SMDM/Group-Assignment/Problem1"

# %%
df_coldstg <- read.csv("Cold_Storage_Temp_Data.csv")
summary(df_coldstg)
# Out:
#     Season        Month          Date        Temperature
#  Rainy :122   Aug    : 31   Min.   : 1.00   Min.   :1.700
#  Summer:120   Dec    : 31   1st Qu.: 8.00   1st Qu.:2.700
#  Winter:123   Jan    : 31   Median :16.00   Median :3.000
#               Jul    : 31   Mean   :15.72   Mean   :3.002
#               Mar    : 31   3rd Qu.:23.00   3rd Qu.:3.300
#               May    : 31   Max.   :31.00   Max.   :4.500
#               (Other):179

# %%
mean(df_coldstg$Temperature)
# Out:
# [1] 3.002466

# %%
sd(df_coldstg$Temperature)
# Out:
# [1] 0.4658319

# %%
summer <- mean(df_coldstg$Temperature[df_coldstg$Season=="Summer"])
print(summer)
# Out:
# [1] 3.1475

# %%
rainy <- mean(df_coldstg$Temperature[df_coldstg$Season=="Rainy"])
print(rainy)
# Out:
# [1] 3.087705

# %%
winter <- mean(df_coldstg$Temperature[df_coldstg$Season=="Winter"])
print(winter)
# Out:
# [1] 2.776423

# %%
X <- (2-3.002466)/0.4658319
pnorm(X)
# Out:
# [1] 0.01569904

# %%
Y <- (4-3.002466)/0.4658319
print(Y)
pnorm(Y, lower.tail = FALSE)
# Out:
# [1] 2.141403
# [1] 0.01612076

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
summary(df_coldstg$Temperature)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.700   2.700   3.000   3.002   3.300   4.500

# %%
A <- pnorm(Y)-pnorm(X)
print(A)
# Out:
# [1] 0.9681802

# %%
a <- pnorm(X)-pnorm((1.7-3.002466)/0.4653819)
b <- pnorm((4.5-3.002466)/0.4653819)-pnorm(Y)
qnorm(0.05)-qnorm(0.025)
# Out:
# [1] 0.3151104

# %%
Z <- pnorm((4.5-3.002466)/0.4653819)-pnorm((1.7-3.002466)/0.4653819)
print(Z)
Z-A
# Out:
# [1] 0.9967888
# [1] 0.02860863

# %% [markdown]
# Inference:
# Since the variation between the specified range and the actual range is 2.8%, the penalty would be 10% of AMC (Annual Maintenance Cost).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
